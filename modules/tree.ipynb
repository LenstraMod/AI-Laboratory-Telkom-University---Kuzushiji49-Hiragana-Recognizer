# %%
import h5py

with h5py.File("../model_kmnist49.h5", "r") as f:
    def print_tree(name, obj):
        print(name)
    f.visititems(print_tree)
# Out:
# model_weights
# model_weights/conv2d_8
# model_weights/conv2d_8/sequential_4
# model_weights/conv2d_8/sequential_4/conv2d_8
# model_weights/conv2d_8/sequential_4/conv2d_8/bias
# model_weights/conv2d_8/sequential_4/conv2d_8/kernel
# model_weights/conv2d_9
# model_weights/conv2d_9/sequential_4
# model_weights/conv2d_9/sequential_4/conv2d_9
# model_weights/conv2d_9/sequential_4/conv2d_9/bias
# model_weights/conv2d_9/sequential_4/conv2d_9/kernel
# model_weights/dense_8
# model_weights/dense_8/sequential_4
# model_weights/dense_8/sequential_4/dense_8
# model_weights/dense_8/sequential_4/dense_8/bias
# model_weights/dense_8/sequential_4/dense_8/kernel
# model_weights/dense_9
# model_weights/dense_9/sequential_4
# model_weights/dense_9/sequential_4/dense_9
# model_weights/dense_9/sequential_4/dense_9/bias
# model_weights/dense_9/sequential_4/dense_9/kernel
# model_weights/dropout_4
# model_weights/flatten_4
# model_weights/max_pooling2d_8
# model_weights/max_pooling2d_9
# ...
